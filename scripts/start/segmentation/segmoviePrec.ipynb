# %%
Testing = True # if True, only 116 time frames are shown in movie

# %% [markdown]
# # Imports

# %%
#-- import functions from my_functions.py file
import sys
sys.path.append('/home/gmaxemin/code/stage-2023-rain-extremes-timing-intensity/scripts/start')
from my_functions import *

import datetime as dt
import re
import cartopy.crs as ccrs
import matplotlib.cm as cm
import psutil
thismodule = sys.modules[__name__]
# Out:
# /data/bfildier/DYAMOND_REGIONS/130E_165E_0N_20N/SAM/2D

# %% [markdown]
# # Paths

# %%
#-- Paths

# DIR_DYAMOND (where DYAMOND data are)

path_DYAMOND_REGIONS = '/data/bfildier/DYAMOND_REGIONS/'
path_reg1_SAM = os.path.join(path_DYAMOND_REGIONS, "130E_165E_0N_20N/SAM")
path_2D = os.path.join(path_reg1_SAM,'2D')

DIR_DYAMOND = path_2D
print(DIR_DYAMOND)

# DIR_DATA (where segmentation relation table is)

DIR_DATA = "/home/gmaxemin/code/stage-2023-rain-extremes-timing-intensity/input/"
# Out:
# /data/bfildier/DYAMOND_REGIONS/130E_165E_0N_20N/SAM/2D

# %%
#-- Correspondence table
df = pd.read_csv(os.path.join(DIR_DATA,'relation_2_table_UTC_dyamond_segmentation.csv'))
df.sort_values(by='UTC',ignore_index=True,inplace=True)
df
# Out:
#       Unnamed: 0  Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.2  \
# 0            476         476.0         476.0         476.0
# 1            443         443.0         443.0         443.0
# 2            468         468.0         468.0         468.0
# 3            432         432.0         432.0         432.0
# 4            437         437.0         437.0         437.0
# ...          ...           ...           ...           ...
# 1914        1295        1295.0        1295.0        1295.0
# 1915        1315        1315.0        1315.0        1315.0
# 1916        1313        1313.0        1313.0        1313.0
# 1917        1304        1304.0        1304.0        1304.0
# 1918        1919           NaN           NaN           NaN
#
#                                            img_seg_path        str_code  \
# 0     data/fiolleau/DYAMOND/TOOCAN/TOOCAN_v2.07/GLOB...   2016-8-1-1-30
# 1     data/fiolleau/DYAMOND/TOOCAN/TOOCAN_v2.07/GLOB...    2016-8-1-2-0
# 2     data/fiolleau/DYAMOND/TOOCAN/TOOCAN_v2.07/GLOB...   2016-8-1-2-30
# 3     data/fiolleau/DYAMOND/TOOCAN/TOOCAN_v2.07/GLOB...    2016-8-1-3-0
# 4     data/fiolleau/DYAMOND/TOOCAN/TOOCAN_v2.07/GLOB...   2016-8-1-3-30
# ...                                                 ...             ...
# 1914  data/fiolleau/DYAMOND/TOOCAN/TOOCAN_v2.07/GLOB...  2016-9-9-22-30
# 1915  data/fiolleau/DYAMOND/TOOCAN/TOOCAN_v2.07/GLOB...   2016-9-9-23-0
# 1916  data/fiolleau/DYAMOND/TOOCAN/TOOCAN_v2.07/GLOB...  2016-9-9-23-30
# 1917  data/fiolleau/DYAMOND/TOOCAN/TOOCAN_v2.07/GLOB...   2016-9-10-0-0
# 1918                                                NaN             NaN
#
#       Unnamed: 0.1  Unnamed: 0.1.1    year  month   day  hour  minute  \
# 0              2.0             2.0  2016.0    8.0   1.0   1.0    30.0
# 1              3.0             3.0  2016.0    8.0   1.0   2.0     0.0
# 2              4.0             4.0  2016.0    8.0   1.0   2.0    30.0
# 3              5.0             5.0  2016.0    8.0   1.0   3.0     0.0
# 4              6.0             6.0  2016.0    8.0   1.0   3.0    30.0
# ...            ...             ...     ...    ...   ...   ...     ...
# 1914        1916.0          1916.0  2016.0    9.0   9.0  22.0    30.0
# 1915        1917.0          1917.0  2016.0    9.0   9.0  23.0     0.0
# 1916        1918.0          1918.0  2016.0    9.0   9.0  23.0    30.0
# 1917        1919.0          1919.0  2016.0    9.0  10.0   0.0     0.0
# 1918           NaN             NaN     NaN    NaN   NaN   NaN     NaN
#
#                                        path_dyamond       UTC
# 0     DYAMOND_9216x4608x74_7.5s_4km_4608_0000000720  17014.03
# 1     DYAMOND_9216x4608x74_7.5s_4km_4608_0000000960  17014.04
# 2     DYAMOND_9216x4608x74_7.5s_4km_4608_0000001200  17014.05
# 3     DYAMOND_9216x4608x74_7.5s_4km_4608_0000001440  17014.06
# 4     DYAMOND_9216x4608x74_7.5s_4km_4608_0000001680  17014.07
# ...                                             ...       ...
# 1914  DYAMOND_9216x4608x74_7.5s_4km_4608_0000460080  17053.45
# 1915  DYAMOND_9216x4608x74_7.5s_4km_4608_0000460320  17053.46
# 1916  DYAMOND_9216x4608x74_7.5s_4km_4608_0000460560  17053.47
# 1917  DYAMOND_9216x4608x74_7.5s_4km_4608_0000460800  17053.48
# 1918                                            NaN  17054.01
#
# [1919 rows x 15 columns]

# %% [markdown]
# # Functions

# %%
def importData(i_t):
    
    # paths
    root_DYAMOND = df.iloc[i_t]['path_dyamond'] + '.%s.2D.nc'
    file_PW_DYAMOND = root_DYAMOND%'PW'
    file_Precac_DYAMOND = root_DYAMOND%'Precac'
    path_TOOCAN = '/'+df.iloc[i_t]['img_seg_path']

    # Check if file exists
    if os.path.exists(os.path.join(DIR_DYAMOND, file_Precac_DYAMOND)):
        # Load DYAMOND data
        Precac_DYAMOND = xr.open_dataarray(os.path.join(DIR_DYAMOND, file_Precac_DYAMOND))
        
        # Load TOOCAN data
        img_TOOCAN = xr.open_dataarray(path_TOOCAN)
    else:
        print("Here")
        # Increase i_t by 1
        i_t += 1
        # Recursive call with the updated i_t
        Precac_DYAMOND, img_TOOCAN = importData(i_t)
    return Precac_DYAMOND, img_TOOCAN

# %%
def getTimeStr(i_t):

    timestamp = df.path_dyamond[i_t].split('_')[-1]
    delta = dt.timedelta(seconds=int(int(timestamp)*7.5))
    date_t = dt.datetime(2016,8,1) + delta
    time_str = dt.datetime.strftime(date_t,"%h %d %Y, %H:%M")

    return time_str

# %%
def getCoords2D(dataset,slice_lon,slice_lat):
    
    # get correct coordinate names in dataset
    for prefix in 'lat','lon':
        r = re.compile("%s.*"%prefix)
        coord = list(filter(r.match,list(dataset.coords.dims)))[0]
        setattr(thismodule,'%s_coord'%prefix,coord)
    
    # extract coordinates
    lat_1D = dataset[lat_coord].sel({lat_coord:slice_lat})
    lon_1D = dataset[lon_coord].sel({lon_coord:slice_lon})

    # compute 2D meshgrid of coordinates
    lonarray,latarray = np.meshgrid(lon_1D,lat_1D)
    
    return lonarray,latarray

# %%
def showColorBar(fig,ax,im):
    
    x,y,w,h = ax.get_position().bounds
    dx = w/60
    cax = plt.axes([x+w+2*dx,y,dx,h])
    cbar = fig.colorbar(im, cax=cax, orientation='vertical')
    cbar.ax.set_ylabel('Surface Accum Precip (mm)')

# %%
def initFigure(i_t0,Lx_fig,Ly_fig,title=None,norm=None):
    # initialize figure
    fig = plt.figure(figsize=(Lx_fig,Ly_fig))
    ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=0))

    ims = []
    ## MY EDIT
    # ims = [[ax.imshow(np.zeros((Ly_fig, Lx_fig))), ax.imshow(np.zeros((Ly_fig, Lx_fig)))] for _ in range(2)]
    
    # for slice_lon in slice(lon_lim[0],360),slice(0,lon_lim[1]):
    for slice_lon in [slice(lon_lim[0], lon_lim[1])]:

        #- background

        # coords
        lonarray_dyamond,latarray_dyamond = getCoords2D(Precac_DYAMOND,slice_lon,slice_lat)            
        # data
        Z = Precac_DYAMOND.sel(lon=slice_lon,lat=slice_lat)[0]
        # log scale
        Z = np.log(Z)

        # show
        im = ax.pcolormesh(lonarray_dyamond,latarray_dyamond,Z,transform=ccrs.PlateCarree(),alpha=0.9,cmap=cmap)
        im.set_clim(*clim)

        #- MCSs
        
        # coords
        lonarray_toocan,latarray_toocan = getCoords2D(img_TOOCAN,slice_lon,slice_lat)            
        # data
        IMG_SEG = img_TOOCAN.sel(longitude=slice_lon,latitude=slice_lat)[0]%10    
        # show
        im_MCS = ax.pcolormesh(lonarray_toocan,latarray_toocan,IMG_SEG,transform=ccrs.PlateCarree(),cmap=cmap_mcs,alpha=1)

        # store image placeholders for later updating
        ims.append([im,im_MCS])

    # delete data and remove from memory
    # del Precac_DYAMOND
    # del img_TOOCAN
    del Z
    del IMG_SEG
    gc.collect()
    
    # cosmetics
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')
    ax.set_title(title)
    showColorBar(fig,ax,im)
        
    # ax.set_extent([lon_lim[0]-360,lon_lim[1], *lat_lim],crs=ccrs.PlateCarree(central_longitude=0))
    ax.coastlines('110m')
    ax.gridlines()
    
    return fig, ax, ims

# %%
def makeMovie(movie_path,j_start,j_end,Lx_fig,Ly_fig):
    
    Nt = len(df)
    
    # -- initialize figure
    
    # first time step
    i_t0 = j_row_t0
    print("i_t0:", i_t0)
    
    title_root = 'DYAMOND-Summer SAM-4km, %s'
    # t_str = "%3.2f"%PW_DYAMOND.time.data[0]
    t_str = getTimeStr(i_t0)
    title = title_root%t_str
    # title = ''
    
    # initialize
    fig, ax, ims = initFigure(i_t0,Lx_fig,Ly_fig,title=title)

    # remove margins~ish
    fig.subplots_adjust(left=0.02)
    
    # -- define movie loop
    
    def updateImage(i_t):

        
        # load data at i_t
        Precac_DYAMOND, img_TOOCAN = importData(i_t)
        
        t_str = getTimeStr(i_t)
        
        # for slice_lon,i_ims in zip([slice(lon_lim[0],360),slice(0,lon_lim[1])],list(np.arange(2))):
        for slice_lon,i_ims in zip([slice(lon_lim[0], lon_lim[1])],list(np.arange(2))):

            Z = Precac_DYAMOND.sel(lon=slice_lon,lat=slice_lat)[0]
            IMG_SEG = img_TOOCAN.sel(longitude=slice_lon,latitude=slice_lat)[0]%10
            
            lonarray_dyamond,latarray_dyamond = getCoords2D(Precac_DYAMOND,slice_lon,slice_lat)

            # update images
            # ims[i_ims][0].set_array(np.ravel(Z[:-1,:-1].data))
            ims[i_ims][0].set_array(np.ravel(Z.data))

            # ims[i_ims][1].set_array(np.ravel(IMG_SEG[:-1,:-1].data))
            ims[i_ims][1].set_array(np.ravel(IMG_SEG.data))



        
        ax.set_title(title_root%t_str)
        
        MB_used = psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2

        # delete data and remove from memory
        # del Precac_DYAMOND
        # del img_TOOCAN
        del Z
        del IMG_SEG
        gc.collect()
        
        return [ims]
    anim = animation.FuncAnimation(fig, updateImage,
                                   frames=range(j_start,j_end), interval=interval, blit=False)
    
    writer = animation.writers['ffmpeg'](fps=frame_rate)

    anim.save(movie_path,writer=writer,dpi=150)#,savefig_kwargs={'bbox_inches':'tight'})

# %% [markdown]
# # Settings

# %%
i_t_chosen = 5

# %%
## image
cmap = plt.cm.RdBu
# cmap_mcs = plt.cm.get_cmap('rainbow', 10)
cmap_mcs = plt.cm.get_cmap('Set3', 12)

clim = (0,70)

# %%
#-- Lon and Lat limits
lon_lim = (130,165)
lat_lim = (0,20)
slice_lat = slice(*lat_lim)

# %%
# load data
Precac_DYAMOND, img_TOOCAN = importData(i_t_chosen)

print(Precac_DYAMOND)
print(img_TOOCAN)
# Out:
# <xarray.DataArray 'Precac' (time: 1, lat: 518, lon: 896)>
# [464128 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float32 0.01931 0.05794 0.09657 0.1352 ... 19.91 19.95 19.99
#   * lon      (lon) float32 130.0 130.1 130.1 130.1 ... 164.9 164.9 164.9 165.0
#   * time     (time) float32 214.2
# Attributes:
#     long_name:  Surface Accum Precip.
#     units:      mm
# <xarray.DataArray 'MCS_label' (time: 1, latitude: 2072, longitude: 9216)>
# [19095552 values with dtype=float32]
# Coordinates:
#   * latitude   (latitude) float32 -40.0 -39.96 -39.92 ... 39.92 39.96 40.0
#   * longitude  (longitude) float32 0.01953 0.05859 0.09766 ... 359.9 359.9 360.0
#   * time       (time) datetime64[ns] 2016-08-01T03:30:00
# Attributes:
#     units:
#     standard_name:  MCS_label
#     long_name:      MCS labellisation
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(

# %%
print(getTimeStr(5))
# Out:
# Aug 01 2016, 04:00

# %% [markdown]
# *test*

# %%
slice_lon = slice(*lon_lim)
getCoords2D(Precac_DYAMOND, slice_lon,slice_lat)
# Out:
# (array([[130.01953, 130.05858, 130.09764, ..., 164.90233, 164.94139,
#          164.98045],
#         [130.01953, 130.05858, 130.09764, ..., 164.90233, 164.94139,
#          164.98045],
#         [130.01953, 130.05858, 130.09764, ..., 164.90233, 164.94139,
#          164.98045],
#         ...,
#         [130.01953, 130.05858, 130.09764, ..., 164.90233, 164.94139,
#          164.98045],
#         [130.01953, 130.05858, 130.09764, ..., 164.90233, 164.94139,
#          164.98045],
#         [130.01953, 130.05858, 130.09764, ..., 164.90233, 164.94139,
#          164.98045]], dtype=float32),
#  array([[1.9314237e-02, 1.9314237e-02, 1.9314237e-02, ..., 1.9314237e-02,
#          1.9314237e-02, 1.9314237e-02],
#         [5.7942707e-02, 5.7942707e-02, 5.7942707e-02, ..., 5.7942707e-02,
#          5.7942707e-02, 5.7942707e-02],
#         [9.6571177e-02, 9.6571177e-02, 9.6571177e-02, ..., 9.6571177e-02,
#          9.6571177e-02, 9.6571177e-02],
#         ...,
#         [1.9912977e+01, 1.9912977e+01, 1.9912977e+01, ..., 1.9912977e+01,
#          1.9912977e+01, 1.9912977e+01],
#         [1.9951607e+01, 1.9951607e+01, 1.9951607e+01, ..., 1.9951607e+01,
#          1.9951607e+01, 1.9951607e+01],
#         [1.9990234e+01, 1.9990234e+01, 1.9990234e+01, ..., 1.9990234e+01,
#          1.9990234e+01, 1.9990234e+01]], dtype=float32))

# %%
del slice_lon

# %% [markdown]
# *test*

# %% [markdown]
# # original:

# %%
## compute figure size
dlon = np.diff(lon_lim)[0] % 360
dlat = np.diff(lat_lim)[0]
Lx_fig = 15
Lx_cbar = 0
Ly_title = 0.5
Ly_fig = (Lx_fig-Lx_cbar)/dlon*dlat + Ly_title
print(Ly_fig)
# Out:
# 9.071428571428571

# %% [markdown]
# # Mine:

# %%
dlon = np.diff(lon_lim)[0] % 360
dlat = np.diff(lat_lim)[0]
Lx_fig = int(dlon / 6)
Ly_fig = int(dlat / 6)

# %%
## time bounds
if Testing == True:
    i_start = 1800
else:
    i_start = 832
i_end = 1916

# %%
# Find first available index
t0_SAM = 200400
root_SAM_t0 = 'DYAMOND_9216x4608x74_7.5s_4km_4608_0000%d'%t0_SAM
j_row_t0 = df.index[df.path_dyamond == root_SAM_t0][0]
print('first available index:',j_row_t0)

if i_start < j_row_t0:
    err_str = "start index is too small (minimum is %d)"%j_row_t0
    raise ValueError(srr_str)
# Out:
# first available index: 832

# %%
# Find last available index
t1_SAM = 460800
root_SAM_t1 = 'DYAMOND_9216x4608x74_7.5s_4km_4608_0000%d'%t1_SAM
j_row_t1 = df.index[df.path_dyamond == root_SAM_t1][0]
print('last available index:',j_row_t1)

if i_end > j_row_t1:
    err_str = "end index is too large (maximum is %d)"%j_row_t1
    raise ValueError(err_str)
# Out:
# last available index: 1917

# %%
Precac_DYAMOND, img_TOOCAN = importData(i_t_chosen)
initFigure(i_t_chosen,Lx_fig,Ly_fig, title="Surface Accum. Precip & MCS")
# Out:
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/core/computation.py:724: RuntimeWarning: divide by zero encountered in log
#   result_data = func(*input_data)
# (<Figure size 360x216 with 2 Axes>,
#  <GeoAxesSubplot:title={'center':'Surface Accum. Precip & MCS'}, xlabel='Longitude', ylabel='Latitude'>,
#  [[<matplotlib.collections.QuadMesh at 0x15431937f8e0>,
#    <matplotlib.collections.QuadMesh at 0x15431937fe20>]])

# %%
movie_path = "segmovietest2.mp4"
## animation
N_frames_per_day = 48
N_days_per_movie_second = 0.25
frame_rate = N_frames_per_day * N_days_per_movie_second
interval = int(1000/frame_rate)

makeMovie(movie_path,i_start,i_end,Lx_fig,Ly_fig)
# Out:
# i_t0: 832
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/xarray/conventions.py:512: SerializationWarning: variable 'MCS_label' has multiple fill values {-999.0, -998.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py", line 251, in saving
#     yield self
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py", line 1157, in save
#     anim._draw_next_frame(d, blit=False)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py", line 1193, in _draw_next_frame
#     self._post_draw(framedata, blit)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py", line 1218, in _post_draw
#     self._fig.canvas.draw_idle()
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/backend_bases.py", line 2012, in draw_idle
#     self.draw(*args, **kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/figure.py", line 1863, in draw
#     mimage._draw_list_compositing_images(
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py", line 479, in draw
#     return matplotlib.axes.Axes.draw(self, renderer=renderer, **kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py", line 411, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 2747, in draw
#     mimage._draw_list_compositing_images(renderer, self, artists)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/collections.py", line 2028, in draw
#     coordinates = transform.transform(coordinates)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/transforms.py", line 1422, in transform
#     res = self.transform_affine(self.transform_non_affine(values))
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/transforms.py", line 2351, in transform_non_affine
#     return self._a.transform_non_affine(points)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py", line 144, in transform_non_affine
#     return prj.transform_points(self.source_projection,
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-34-13d9278d7544>", line 8, in <module>
#     makeMovie(movie_path,i_start,i_end,Lx_fig,Ly_fig)
#   File "<ipython-input-20-9d175dc51f38>", line 68, in makeMovie
#     anim.save(movie_path,writer=writer,dpi=150)#,savefig_kwargs={'bbox_inches':'tight'})
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py", line 1161, in save
#     writer.grab_frame(**savefig_kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py", line 253, in saving
#     self.finish()
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py", line 354, in finish
#     self.cleanup()
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py", line 390, in cleanup
#     raise subprocess.CalledProcessError(
# subprocess.CalledProcessError: Command '['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '750x450', '-pix_fmt', 'rgba', '-r', '12.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', 'segmovietest2.mp4']' returned non-zero exit status 255.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'CalledProcessError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/inspect.py", line 751, in getmodule
#     f = getabsfile(module)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/inspect.py", line 720, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/inspect.py", line 705, in getsourcefile
#     if os.path.exists(filename):
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py", line 251, in saving
#     yield self
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py", line 1157, in save
#     anim._draw_next_frame(d, blit=False)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py", line 1193, in _draw_next_frame
#     self._post_draw(framedata, blit)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py", line 1218, in _post_draw
#     self._fig.canvas.draw_idle()
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/backend_bases.py", line 2012, in draw_idle
#     self.draw(*args, **kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/figure.py", line 1863, in draw
#     mimage._draw_list_compositing_images(
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py", line 479, in draw
#     return matplotlib.axes.Axes.draw(self, renderer=renderer, **kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py", line 411, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 2747, in draw
#     mimage._draw_list_compositing_images(renderer, self, artists)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/collections.py", line 2028, in draw
#     coordinates = transform.transform(coordinates)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/transforms.py", line 1422, in transform
#     res = self.transform_affine(self.transform_non_affine(values))
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/transforms.py", line 2351, in transform_non_affine
#     return self._a.transform_non_affine(points)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py", line 144, in transform_non_affine
#     return prj.transform_points(self.source_projection,
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-34-13d9278d7544>", line 8, in <module>
#     makeMovie(movie_path,i_start,i_end,Lx_fig,Ly_fig)
#   File "<ipython-input-20-9d175dc51f38>", line 68, in makeMovie
#     anim.save(movie_path,writer=writer,dpi=150)#,savefig_kwargs={'bbox_inches':'tight'})
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py", line 1161, in save
#     writer.grab_frame(**savefig_kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py", line 253, in saving
#     self.finish()
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py", line 354, in finish
#     self.cleanup()
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py", line 390, in cleanup
#     raise subprocess.CalledProcessError(
# subprocess.CalledProcessError: Command '['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '750x450', '-pix_fmt', 'rgba', '-r', '12.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', 'segmovietest2.mp4']' returned non-zero exit status 255.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'CalledProcessError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3454, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2063, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/posixpath.py", line 391, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/posixpath.py", line 425, in _joinrealpath
#     if not islink(newpath):
#   File "/net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/posixpath.py", line 167, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     250         try:
# --> 251             yield self
#     252         finally:
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1156                     # TODO: See if turning off blit is really necessary
# -> 1157                     anim._draw_next_frame(d, blit=False)
#    1158                     if progress_callback is not None:
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#    1192         self._draw_frame(framedata)
# -> 1193         self._post_draw(framedata, blit)
#    1194
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py in _post_draw(self, framedata, blit)
#    1217         else:
# -> 1218             self._fig.canvas.draw_idle()
#    1219
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2011             with self._idle_draw_cntx():
# -> 2012                 self.draw(*args, **kwargs)
#    2013
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py in draw(self, renderer, **kwargs)
#     478
# --> 479         return matplotlib.axes.Axes.draw(self, renderer=renderer, **kwargs)
#     480
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/collections.py in draw(self, renderer)
#    2027             coordinates = self._coordinates.reshape((-1, 2))
# -> 2028             coordinates = transform.transform(coordinates)
#    2029             coordinates = coordinates.reshape(self._coordinates.shape)
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/transforms.py in transform(self, values)
#    1421         # Transform the values
# -> 1422         res = self.transform_affine(self.transform_non_affine(values))
#    1423
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/transforms.py in transform_non_affine(self, points)
#    2350         elif not self._a.is_affine and self._b.is_affine:
# -> 2351             return self._a.transform_non_affine(points)
#    2352         else:
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py in transform_non_affine(self, xy)
#     143         if isinstance(xy, np.ndarray):
# --> 144             return prj.transform_points(self.source_projection,
#     145                                         xy[:, 0], xy[:, 1])[:, 0:2]
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-34-13d9278d7544> in <module>
#       7
# ----> 8 makeMovie(movie_path,i_start,i_end,Lx_fig,Ly_fig)
#
# <ipython-input-20-9d175dc51f38> in makeMovie(movie_path, j_start, j_end, Lx_fig, Ly_fig)
#      67
# ---> 68     anim.save(movie_path,writer=writer,dpi=150)#,savefig_kwargs={'bbox_inches':'tight'})
#      69
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1160                         frame_number += 1
# -> 1161                 writer.grab_frame(**savefig_kwargs)
#    1162
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     252         finally:
# --> 253             self.finish()
#     254
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py in finish(self)
#     353         """Finish any processing for writing the movie."""
# --> 354         self.cleanup()
#     355
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/matplotlib/animation.py in cleanup(self)
#     389         if self._proc.returncode:
# --> 390             raise subprocess.CalledProcessError(
#     391                 self._proc.returncode, self._proc.args, out, err)
#
# CalledProcessError: Command '['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '750x450', '-pix_fmt', 'rgba', '-r', '12.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', 'segmovietest2.mp4']' returned non-zero exit status 255.
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'CalledProcessError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3356                         asy = compare(code)
# -> 3357                     if (await self.run_code(code, result,  async_=asy)):
#    3358                         return True
#
#     [... skipping hidden 1 frame]
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/async_helpers.py in _pseudo_sync_runner(coro)
#      66     """
#      67     try:
# ---> 68         coro.send(None)
#      69     except StopIteration as exc:
#      70         return exc.value
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple)
#    3163                     interactivity = 'async'
#    3164
# -> 3165                 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3166                        interactivity=interactivity, compiler=compiler, result=result)
#    3167
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3374             if result:
#    3375                 result.error_before_exec = sys.exc_info()[1]
# -> 3376             self.showtraceback()
#    3377             return True
#    3378
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2061                         stb = value._render_traceback_()
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#    2065
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1140         chained_exc_ids = set()
#    1141         while evalue:
# -> 1142             formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#    1143                                                                      chained_exceptions_tb_offset)
#    1144             exception = self.get_parts_of_chained_exception(evalue)
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /net/nfs/tools/u20/Python/anaconda-2021.11/envs/meso-3.8/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
